# %%
import os, json
from dotenv import load_dotenv, find_dotenv; _ = load_dotenv(find_dotenv())

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough

# %%
topic_type = 'foods'
prompt_file = f'{topic_type}_prompt.txt'
topic_file = f'{topic_type}.txt'

# %%
with open(f'config/{topic_file}', 'r') as f:
    topic_list = f.read().splitlines()
topic_list
# Out:
# ['じゃがいも', '玉ねぎ', 'にんじん', 'なす', 'トマト', 'ピーマン']

# %%
with open(f'config/{prompt_file}', 'r') as f:
    template_str = f.read()
print(template_str)
# Out:
# ユーザーが入力する食材について、1000字程度の詳細な解説を生成してください。
# 原産国、栽培方法、栄養、調理方法、風味、旬の季節、相性のよい食材や調味料や調理方法、その他の特徴に言及してください。

# %% [markdown]
# ## Generate prose chain

# %%
prompt_template = ChatPromptTemplate.from_messages([
    ('system', template_str),
    ('user', '{food_name}')
])

chat = ChatOpenAI(model='gpt-3.5-turbo-0125', temperature=0., max_tokens=4096)

generate_prose_chain = (
    {'food_name': RunnablePassthrough()}
    | prompt_template
    | chat
)

# %% [markdown]
# ### Test

# %%
# res = generate_prose_chain.invoke(topic_list[0])
# print(res)

# %%
# print(len(res.content))

# %% [markdown]
# ### Batch

# %%
res = generate_prose_chain.batch(topic_list)
full_prose_texts = [(t, r.content) for t,r in zip(topic_list,res)]

# %%
for topic,text in full_prose_texts:
    print(topic, len(text), '='*30)
    print(text)
    os.makedirs(f'data/{topic_type}/{topic}', exist_ok=True)
    with open(f'./data/{topic_type}/{topic}/ja-prose-full.txt', 'w') as f:
        f.write(text)
# Out:
# じゃがいも 606 ==============================
# じゃがいもは、南アメリカ原産の野菜で、世界中で広く栽培されている主食として知られています。日本でも古くから栽培され、多くの家庭で親しまれている食材です。
#
# じゃがいもは、寒冷な気候での栽培が適しており、日本国内では北海道や青森などの地域で生産されています。栄養価も高く、ビタミンCやカリウム、食物繊維が豊富に含まれています。特に皮ごと食べることで、食物繊維を摂取することができます。
#
# 調理方法としては、茹でる、焼く、揚げる、蒸すなどさまざまな方法があります。特にポテトサラダやポテトフライ、ポテトグラタンなど、洋食の定番料理に使われることが多いです。また、和食でも煮物や炒め物に加えられることもあります。
#
# 風味は、甘みとほくほくした食感が特徴で、調理方法によってさまざまな味わいを楽しむことができます。旬の季節は秋から冬で、収穫後は日持ちが良いため、長期間保存することができます。
#
# じゃがいもは、肉類や野菜との相性が良く、玉ねぎやニンニク、ローズマリー、オリーブオイルなどとの組み合わせもおすすめです。また、じゃがいもを蒸かしてから調理すると、さらにふんわりとした食感を楽しむことができます。
#
# その他の特徴としては、じゃがいもは皮ごと食べられるため、栄養価を最大限に活かすことができます。また、じゃがいもの種類には、サラダ用や煮崩れしにくい種類などさまざまな種類があり、料理に合わせて選ぶことができます。
# 玉ねぎ 689 ==============================
# 玉ねぎは、ユリ科の植物で、世界中で広く栽培されている野菜です。原産地は中央アジアと言われており、古代エジプトや古代ローマでも栽培されていました。現在では、日本を含む多くの国で栽培されています。
#
# 玉ねぎは一年中市場で入手できますが、旬の時期は夏から秋にかけてです。栽培方法としては、種まきや苗を植え付けて栽培することが一般的です。日当たりの良い場所や水はけの良い土壌が適しています。
#
# 玉ねぎにはビタミンCや食物繊維、カリウムなどが豊富に含まれており、免疫力を高めたり、消化を助けたりする効果があります。また、硫化アリルという成分が含まれており、抗菌作用や血液をサラサラにする効果もあります。
#
# 玉ねぎは生でも調理しても美味しく食べることができます。生のままスライスしてサラダに入れたり、薄切りにしてサンドイッチに挟んだりするのもおすすめです。炒めると甘みが増し、カラメル化して甘みが引き立ちます。スープやシチュー、カレーなどの料理にもよく使われます。
#
# 玉ねぎは他の食材との相性も良く、肉料理や魚料理、野菜料理など幅広い料理に活用できます。また、調味料としても使われ、マリネやドレッシング、ソースなどにも欠かせない食材です。
#
# 玉ねぎは切ると涙が出ることで知られていますが、冷蔵庫で冷やしてから切ると涙を抑えることができます。また、切った後は水にさらすと辛みが和らぎます。その他にも、玉ねぎの皮は栄養価が高く、スープやだしに使うことで無駄なく利用することができます。
#
# 玉ねぎは料理に欠かせない食材であり、その独特の風味や栄養価、幅広い使い道から、多くの人々に愛されています。
# にんじん 605 ==============================
# にんじんは、ユリ科の植物で、主に根菜として知られています。原産地は中央アジアで、古代から栽培されていた歴史があります。現在では世界中で栽培されており、日本でも一年中手に入りやすい野菜の一つです。
#
# にんじんは、日光をたっぷり浴びて育つことで甘味が増し、栄養価も高まります。特にβ-カロテンやビタミンC、食物繊維が豊富で、免疫力を高める効果や美肌効果が期待できます。また、消化器官の働きを助け、便秘解消にも役立ちます。
#
# にんじんは生でも調理しても美味しく食べられる万能食材です。生のままサラダやスティック状に切ってディップにするのも良いですし、煮物や炒め物、スープに入れても美味しいです。特に、にんじんジュースは栄養価が高く、健康効果が期待できます。
#
# にんじんの風味は甘みがあり、独特の香りがします。旬の季節は秋から冬で、寒い季節に収穫されるにんじんは甘味が増しています。にんじんは、玉ねぎやセロリ、ジャガイモと一緒に煮込むと相性が良く、野菜の甘みが引き立ちます。また、にんじんはオリーブオイルやハチミツ、レモンとも相性が良いです。
#
# その他の特徴として、にんじんは保存が比較的容易で、冷暗所に保存すれば1〜2週間は新鮮な状態を保つことができます。また、皮を剥いてから保存すると鮮度を保ちやすいです。にんじんは調理方法や相性の良い食材によって様々な料理に活用できるので、食卓に欠かせない食材の一つと言えます。
# なす 457 ==============================
# なすは、茄子（なすび）とも呼ばれ、ナス科の植物である。原産地はインドで、古くからアジア全域で栽培されている。日本でも夏野菜として親しまれており、主に5月から10月にかけて旬を迎える。
#
# なすは、栄養価が高く、食物繊維やビタミンC、カリウム、マグネシウムなどが豊富に含まれている。特に皮に多く含まれる食物繊維は便秘解消や血糖値の上昇を抑える効果がある。
#
# 調理方法としては、炒め物や煮物、揚げ物、焼き物などさまざまな料理に活用される。特に炒めると甘みが増し、トロッとした食感が楽しめる。また、なすの風味を生かすためには、塩水につけて苦みを抜いたり、油を吸わせるために揚げる前に軽く焼くと良い。
#
# なすは、トマトやピーマン、玉ねぎ、にんにくなどと相性が良く、ラタトゥイユや中華料理の具材としてもよく使われる。また、味噌や醤油、ごま油、唐辛子などとの相性も良い。
#
# なすは、夏野菜として夏の暑い時期に栄養補給をするのに最適であり、軽やかな味わいと食感が暑い季節にぴったりだ。そのため、夏野菜の代表格として親しまれている。
# トマト 532 ==============================
# トマトは南アメリカ原産の野菜で、現在では世界中で広く栽培されています。トマトは一年中市場で入手可能であり、生食や調理に幅広く利用されています。
#
# 栄養面では、トマトにはビタミンC、ビタミンK、ビタミンA、カリウム、リコピンなどが豊富に含まれています。特にリコピンは抗酸化作用があり、がん予防や心臓病のリスク低減に効果があるとされています。
#
# トマトは生食や加熱調理どちらでも美味しく食べることができます。生のトマトはサラダやサンドイッチ、スライスしてそのまま食べるのが一般的です。一方、加熱調理するとトマトの甘みが引き立ち、トマトソースやスープ、煮込み料理などに利用されます。
#
# トマトの風味は甘みと酸味がバランスよく、爽やかな味わいが特徴です。トマトは夏から秋が旬で、この時期には特に美味しさが際立ちます。
#
# トマトは他の野菜やハーブとの相性が良く、玉ねぎやニンニク、バジル、オリーブオイルなどとの組み合わせがおすすめです。トマトソースには砂糖や塩、ワインなどを加えて味を調えることが一般的です。
#
# トマトの特徴として、色や形がさまざまであり、赤、黄色、オレンジなどの色合いがあります。また、ビーフステーキトマトやプチトマトなど、サイズも異なる品種が存在します。
# ピーマン 592 ==============================
# ピーマンは、南アメリカ原産のナス科の植物で、世界中で広く栽培されている野菜です。日本では夏から秋にかけて旬を迎え、スーパーなどで手軽に入手できます。
#
# ピーマンは比較的育てやすい野菜で、温暖な気候を好みます。日当たりの良い場所で、水はけの良い土壌で栽培されると良い収穫が期待できます。また、ピーマンは栄養価が高く、ビタミンCやカリウム、食物繊維が豊富に含まれています。
#
# 調理方法としては、ピーマンは生でも調理しても美味しく食べることができます。生のままサラダに入れたり、炒め物や煮物、揚げ物に使うことが一般的です。ピーマンの風味は独特で、苦味や甘みがあります。種を取り除くことで苦味を抑えることもできます。
#
# ピーマンは他の野菜や調味料とも相性が良く、玉ねぎやにんにく、トマトと一緒に使うことが多いです。また、肉や魚介類との相性も良く、炒め物や煮物に合わせると美味しいです。調理方法としては、炒める、煮る、焼く、揚げるなど様々な方法で調理することができます。
#
# ピーマンは低カロリーでありながら食物繊維が豊富なため、ダイエット中の方にもおすすめの食材です。また、ビタミンCが豊富なので、免疫力アップや美肌効果も期待できます。
#
# ピーマンは色々な料理に活用できる万能な食材であり、その独特の風味や栄養価から、健康的で美味しい食事を楽しむために積極的に取り入れてみてはいかがでしょうか。
